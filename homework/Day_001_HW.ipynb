# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)**2
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 0.130

# %%
作業一
我選擇"Air quality data from extensive network of sensors"這個主題
1.因現在空氣盒子愈裝愈多，但是數據分析靠人工過於緩慢，因此想用快速的方法與精簡的人力，完成這件事。
2.資料將用空氣盒子或是以網站上Krakow, Poland提供的資料為主。
3.他的資料以CSV檔為主，為各月份監測數據。
4.篩選數據中異常值、並將數據應用於統計分析或找尋污染物傳遞趨勢。
作業二
1.載客客群與服務，了解客群與時間，可有效利用及對不同對象宣傳
2.資料以公司的長期客群資料為主，散客對於統計蒐集來說較不利，因無固定出現時間與頻率
3.資料為統計數據，以數據或紙本資料為主
4.哪時候適合去接人、地點及去何處發送宣傳資訊較為妥當
